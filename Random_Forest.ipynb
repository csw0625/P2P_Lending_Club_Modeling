# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, classification_report
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

df_tv = pd.read_csv("train_ind_prc.csv")
df_test = pd.read_csv("test_ind_prc.csv")
df_tv = df_tv.drop(['num__installment'], axis=1)
df_test = df_test.drop(['num__installment'], axis=1)


df_tv_exiti = df_tv.drop(['rf_rate','REAL_IRR'], axis=1)
df_test_exiti = df_test.drop(['rf_rate','REAL_IRR'], axis=1)

# %%
def cal_IRR(row):
    if row['pred_y'] == 1:
        return row['rf_rate']
    elif row['pred_y'] == 0:
        return row['REAL_IRR']
    else:
        return None

def cal_SR(df):
    excess_returns = df['IRR'] - df['rf_rate']
    if excess_returns.std() == 0:
        return 0
    return excess_returns.mean() / excess_returns.std()

# %%
# 최적 하이퍼파라미터를 찾기 위해 샘플 스플릿 with seed 0

X_tv = df_tv.drop('y', axis=1)
X_test = df_test.drop('y', axis=1)
y_tv = df_tv['y']
y_test = df_test['y']

X_train_R, X_val_R, y_train, y_val = train_test_split(X_tv, y_tv, stratify=y_tv, test_size=0.1, random_state=0)

X_train = X_train_R.drop(["rf_rate", "REAL_IRR"], axis=1) 
X_val = X_val_R.drop(["rf_rate", "REAL_IRR"], axis=1)

th = np.linspace(0.01, 0.99, 50)

import optuna
from optuna.samplers import TPESampler

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 300, step=100),
        'max_depth': trial.suggest_int('max_depth', 10, 30),
        'min_samples_split': trial.suggest_int('min_samples_split', 200, 500),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 3, 5),
        'max_features': trial.suggest_categorical('max_features', ['sqrt']),
        'class_weight': {0: 0.82, 1: 0.18},
        'criterion' : 'entropy'
    }

    model = RandomForestClassifier(**params)
    model.fit(X_train, y_train)
    pred_y_proba = model.predict_proba(X_val)[:,1]
    best_sr = -np.inf
    for t in th:
        pred_y = (pred_y_proba >= t).astype(int)
        X_val_R_copy = X_val_R.copy()
        X_val_R_copy['pred_y'] = pred_y
        X_val_R_copy['IRR'] = X_val_R_copy.apply(cal_IRR, axis=1)
        sr = cal_SR(X_val_R_copy)
        if sr > best_sr:
            best_sr = sr

    return best_sr

def optuna_rf(n_trials):
    best_results = []
    study = optuna.create_study(
        direction='maximize',
        study_name='rf_TPE',
        sampler=TPESampler(multivariate=True, group=True)
    )
    study.optimize(lambda trial: objective(trial), n_trials=n_trials)
    best_sr = study.best_value
    best_params = study.best_params
    best_results.append({
            'Sharpe': best_sr, 
            'params': best_params,
        })
    return best_results

best_results = optuna_rf(n_trials=20)
# Out:
# [I 2025-08-21 18:14:39,682] A new study created in memory with name: rf_TPE
# [I 2025-08-21 18:21:49,928] Trial 0 finished with value: 0.17635385897686734 and parameters: {'n_estimators': 200, 'max_depth': 18, 'min_samples_split': 375, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.17635385897686734.
# [I 2025-08-21 18:30:00,094] Trial 1 finished with value: 0.17887226380842816 and parameters: {'n_estimators': 200, 'max_depth': 23, 'min_samples_split': 254, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.17887226380842816.
# [I 2025-08-21 18:42:25,090] Trial 2 finished with value: 0.17845788447063526 and parameters: {'n_estimators': 300, 'max_depth': 25, 'min_samples_split': 357, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.17887226380842816.
# [I 2025-08-21 18:53:17,967] Trial 3 finished with value: 0.1805179053215377 and parameters: {'n_estimators': 300, 'max_depth': 17, 'min_samples_split': 265, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.1805179053215377.
# [I 2025-08-21 19:03:12,994] Trial 4 finished with value: 0.17792948928944427 and parameters: {'n_estimators': 300, 'max_depth': 15, 'min_samples_split': 237, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.1805179053215377.
# [I 2025-08-21 19:10:56,348] Trial 5 finished with value: 0.17134874805033148 and parameters: {'n_estimators': 300, 'max_depth': 11, 'min_samples_split': 464, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.1805179053215377.
# [I 2025-08-21 19:18:51,088] Trial 6 finished with value: 0.18130789795807878 and parameters: {'n_estimators': 200, 'max_depth': 21, 'min_samples_split': 288, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.18130789795807878.
# [I 2025-08-21 19:31:09,666] Trial 7 finished with value: 0.1809116399755477 and parameters: {'n_estimators': 300, 'max_depth': 25, 'min_samples_split': 246, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.18130789795807878.
# [I 2025-08-21 19:34:34,813] Trial 8 finished with value: 0.17661064357580508 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 367, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.18130789795807878.
# [I 2025-08-21 19:45:50,323] Trial 9 finished with value: 0.1763583154354558 and parameters: {'n_estimators': 300, 'max_depth': 30, 'min_samples_split': 477, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.18130789795807878.
# [I 2025-08-21 19:53:14,976] Trial 10 finished with value: 0.17785214049054673 and parameters: {'n_estimators': 200, 'max_depth': 17, 'min_samples_split': 204, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.18130789795807878.
# [I 2025-08-21 20:05:32,553] Trial 11 finished with value: 0.17951282498772314 and parameters: {'n_estimators': 300, 'max_depth': 25, 'min_samples_split': 292, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.18130789795807878.
# [I 2025-08-21 20:14:04,901] Trial 12 finished with value: 0.183892293585871 and parameters: {'n_estimators': 200, 'max_depth': 27, 'min_samples_split': 213, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.183892293585871.
# [I 2025-08-21 20:22:37,819] Trial 13 finished with value: 0.17994827182740378 and parameters: {'n_estimators': 200, 'max_depth': 29, 'min_samples_split': 211, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.183892293585871.
# [I 2025-08-21 20:26:36,568] Trial 14 finished with value: 0.17922550280681168 and parameters: {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 316, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.183892293585871.
# [I 2025-08-21 20:30:53,878] Trial 15 finished with value: 0.18413073585982961 and parameters: {'n_estimators': 100, 'max_depth': 24, 'min_samples_split': 200, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.18413073585982961.
# [I 2025-08-21 20:35:04,043] Trial 16 finished with value: 0.18005020493739643 and parameters: {'n_estimators': 100, 'max_depth': 28, 'min_samples_split': 337, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.18413073585982961.
# [I 2025-08-21 20:39:23,305] Trial 17 finished with value: 0.18047708606233884 and parameters: {'n_estimators': 100, 'max_depth': 26, 'min_samples_split': 210, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.18413073585982961.
# [I 2025-08-21 20:43:21,682] Trial 18 finished with value: 0.17911837014145382 and parameters: {'n_estimators': 100, 'max_depth': 18, 'min_samples_split': 227, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.18413073585982961.
# [I 2025-08-21 20:46:28,881] Trial 19 finished with value: 0.17393639994928778 and parameters: {'n_estimators': 100, 'max_depth': 13, 'min_samples_split': 486, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.18413073585982961.

# %%
param = {
    'n_estimators': 100,
    'max_depth': 24,
    'min_samples_split': 200,
    'min_samples_leaf': 4,
    'max_features': 'sqrt'
}

# %%
from sklearn.utils import resample

def bootstrap_threshold_optimization(df_tv, n_bootstrap, n_thresholds):
    bootstrap_results = []

    for i in range(n_bootstrap):
        print(f"\n=== Bootstrap {i+1}/{n_bootstrap} ===")
        
        # Bootstrap sampling
        df_boot = resample(df_tv, replace=True, n_samples=len(df_tv), random_state=i)
        X_tv = df_boot.drop('y', axis=1)
        y_tv = df_boot['y']
        X_test_R = df_test.drop('y', axis=1)

        X_train_R, X_val_R, y_train, y_val = train_test_split(X_tv, y_tv, stratify=y_tv, test_size=0.1, random_state=0)

        X_train = X_train_R.drop(["rf_rate", "REAL_IRR"], axis=1) 
        X_val = X_val_R.drop(["rf_rate", "REAL_IRR"], axis=1)
        X_test = X_test_R.drop(["rf_rate", "REAL_IRR"], axis=1)

        # Train model with fixed optimal parameters
        model = RandomForestClassifier(**param)
        model.fit(X_train, y_train)
        pred_y_proba = model.predict_proba(X_test)[:, 1]

        # Search for best threshold only (constrain to [0, 1] range)
        thresholds = np.linspace(0.01, 0.99, n_thresholds)
        best_sr = -np.inf
        best_th = 0.5
        
        for th in thresholds:
            # pred_y = 1 if probability >= threshold (predict default)
            # pred_y = 0 if probability < threshold (predict no default, so invest)
            pred_y = (pred_y_proba > th).astype(int)
            X_test_copy = X_test_R.copy()
            X_test_copy['pred_y'] = pred_y
            X_test_copy['IRR'] = X_test_copy.apply(cal_IRR, axis=1)
            sr = cal_SR(X_test_copy)
            if sr > best_sr:
                best_sr = sr
                best_th = th
        bootstrap_results.append({
            'Bootstrap': i+1,
            'Sharpe': best_sr, 
            'threshold': best_th
        })
        
        print(f"Bootstrap {i+1}: Best Sharpe={best_sr:.4f}, Threshold={best_th:.3f}")

    return bootstrap_results

print("Running bootstrap threshold optimization with fixed hyperparameters...")
bootstrap_results = bootstrap_threshold_optimization(df_tv, n_bootstrap=30, n_thresholds=20)

# Display results
results_df = pd.DataFrame(bootstrap_results)
print("\n=== Final Results ===")
print(results_df[['Bootstrap', 'Sharpe', 'threshold']])
print(f"\nMean Sharpe: {results_df['Sharpe'].mean():.4f}")
print(f"Mean Threshold: {results_df['threshold'].mean():.4f}")
print(f"Std Sharpe: {results_df['Sharpe'].std():.4f}")
print(f"Best Sharpe: {results_df['Sharpe'].max():.4f}")

# Plot results
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Histogram of Sharpe ratios
ax1.hist(results_df['Sharpe'], bins=15, alpha=0.7, color='skyblue', edgecolor='black')
ax1.axvline(results_df['Sharpe'].mean(), color='red', linestyle='--', 
           label=f'Mean: {results_df["Sharpe"].mean():.4f}')
ax1.set_xlabel('Sharpe Ratio')
ax1.set_ylabel('Frequency')
ax1.set_title('Distribution of Bootstrap Sharpe Ratios')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Histogram of thresholds
ax2.hist(results_df['threshold'], bins=15, alpha=0.7, color='lightgreen', edgecolor='black')
ax2.axvline(results_df['threshold'].mean(), color='red', linestyle='--',
           label=f'Mean: {results_df["threshold"].mean():.3f}')
ax2.set_xlabel('Optimal Threshold')
ax2.set_ylabel('Frequency')
ax2.set_title('Distribution of Optimal Thresholds')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Running bootstrap threshold optimization with fixed hyperparameters...
#
# === Bootstrap 1/30 ===
# Bootstrap 1: Best Sharpe=0.1827, Threshold=0.165
#
# === Bootstrap 2/30 ===
# Bootstrap 2: Best Sharpe=0.1836, Threshold=0.165
#
# === Bootstrap 3/30 ===
# Bootstrap 3: Best Sharpe=0.1839, Threshold=0.165
#
# === Bootstrap 4/30 ===
# Bootstrap 4: Best Sharpe=0.1827, Threshold=0.165
#
# === Bootstrap 5/30 ===
# Bootstrap 5: Best Sharpe=0.1830, Threshold=0.165
#
# === Bootstrap 6/30 ===
# Bootstrap 6: Best Sharpe=0.1839, Threshold=0.165
#
# === Bootstrap 7/30 ===
# Bootstrap 7: Best Sharpe=0.1842, Threshold=0.165
#
# === Bootstrap 8/30 ===
# Bootstrap 8: Best Sharpe=0.1833, Threshold=0.165
#
# === Bootstrap 9/30 ===
# Bootstrap 9: Best Sharpe=0.1834, Threshold=0.165
#
# === Bootstrap 10/30 ===
# Bootstrap 10: Best Sharpe=0.1827, Threshold=0.165
#
# === Bootstrap 11/30 ===
# Bootstrap 11: Best Sharpe=0.1832, Threshold=0.165
#
# === Bootstrap 12/30 ===
# Bootstrap 12: Best Sharpe=0.1840, Threshold=0.165
#
# === Bootstrap 13/30 ===
# Bootstrap 13: Best Sharpe=0.1830, Threshold=0.165
#
# === Bootstrap 14/30 ===
# Bootstrap 14: Best Sharpe=0.1840, Threshold=0.165
#
# === Bootstrap 15/30 ===
# Bootstrap 15: Best Sharpe=0.1841, Threshold=0.165
#
# === Bootstrap 16/30 ===
# Bootstrap 16: Best Sharpe=0.1828, Threshold=0.165
#
# === Bootstrap 17/30 ===
# Bootstrap 17: Best Sharpe=0.1841, Threshold=0.165
#
# === Bootstrap 18/30 ===
# Bootstrap 18: Best Sharpe=0.1833, Threshold=0.165
#
# === Bootstrap 19/30 ===
# Bootstrap 19: Best Sharpe=0.1826, Threshold=0.165
#
# === Bootstrap 20/30 ===
# Bootstrap 20: Best Sharpe=0.1836, Threshold=0.165
#
# === Bootstrap 21/30 ===
# Bootstrap 21: Best Sharpe=0.1833, Threshold=0.165
#
# === Bootstrap 22/30 ===
# Bootstrap 22: Best Sharpe=0.1837, Threshold=0.165
#
# === Bootstrap 23/30 ===
# Bootstrap 23: Best Sharpe=0.1842, Threshold=0.165
#
# === Bootstrap 24/30 ===
# Bootstrap 24: Best Sharpe=0.1824, Threshold=0.165
#
# === Bootstrap 25/30 ===
# Bootstrap 25: Best Sharpe=0.1844, Threshold=0.165
#
# === Bootstrap 26/30 ===
# Bootstrap 26: Best Sharpe=0.1837, Threshold=0.165
#
# === Bootstrap 27/30 ===
# Bootstrap 27: Best Sharpe=0.1838, Threshold=0.165
#
# === Bootstrap 28/30 ===
# Bootstrap 28: Best Sharpe=0.1843, Threshold=0.165
#
# === Bootstrap 29/30 ===
# Bootstrap 29: Best Sharpe=0.1843, Threshold=0.165
#
# === Bootstrap 30/30 ===
# Bootstrap 30: Best Sharpe=0.1837, Threshold=0.165
#
# === Final Results ===
#     Bootstrap    Sharpe  threshold
# 0           1  0.182745   0.164737
# 1           2  0.183588   0.164737
# 2           3  0.183924   0.164737
# 3           4  0.182652   0.164737
# 4           5  0.183011   0.164737
# 5           6  0.183931   0.164737
# 6           7  0.184161   0.164737
# 7           8  0.183277   0.164737
# 8           9  0.183435   0.164737
# 9          10  0.182657   0.164737
# 10         11  0.183161   0.164737
# 11         12  0.183988   0.164737
# 12         13  0.182960   0.164737
# 13         14  0.184029   0.164737
# 14         15  0.184111   0.164737
# 15         16  0.182792   0.164737
# 16         17  0.184141   0.164737
# 17         18  0.183333   0.164737
# 18         19  0.182578   0.164737
# 19         20  0.183643   0.164737
# 20         21  0.183276   0.164737
# 21         22  0.183702   0.164737
# 22         23  0.184219   0.164737
# 23         24  0.182350   0.164737
# 24         25  0.184359   0.164737
# 25         26  0.183701   0.164737
# 26         27  0.183832   0.164737
# 27         28  0.184268   0.164737
# 28         29  0.184335   0.164737
# 29         30  0.183738   0.164737
#
# Mean Sharpe: 0.1835
# Mean Threshold: 0.1647
# Std Sharpe: 0.0006
# Best Sharpe: 0.1844
